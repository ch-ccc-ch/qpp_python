# %%
# import openprompt

# %%
#401-450d1000.txt: https://drive.google.com/file/d/1lY6JGPtMy72rPRX5a0ieXBY7T334Mn1X/view?usp=sharing

# %%
# import csv
# csv.field_size_limit(1410720)

#Initialize Dictionary

# trec_dict = {}
# q_dict = {}
# query_id_counts = {}


## Reading data from trec.txt

# with open('401-450.txt', 'r') as f:
#     reader = csv.reader(f, delimiter='\t')
#     for row in reader:
#         query_id = row[0]  # queryid
#         query_content = row[1]  # query content
#         trec_dict[query_id] = query_content

# # Reading data from lmdir.txt
# with open('401-450d1000.txt', 'r') as f:
#     reader = csv.reader(f, delimiter='\t')
#     for row in reader:
#         query_id = row[0]  
#         doc_content = row[6]  
#         if query_id_counts.get(query_id, 0) >= 5:
#             continue
        
        

#         key = query_id + '\t' + trec_dict.get(query_id, '')
#         i = len(q_dict.get(key, []))+1
#         doc_content = f'Document {i} : {doc_content}'
        
#         if key in q_dict:
#             q_dict[key].append(doc_content)
#         else:
#             q_dict[key] = []
#             q_dict[key].append(doc_content)
            
#         query_id_counts[query_id] = query_id_counts.get(query_id, 0) + 1



# for query_id in list(q_dict.keys())[:1]:
#     print("Query :", query_id)
#     print("Document Contents:", q_dict[query_id])

# %%
# # q_dict['264014	how long is life cycle of flea']
# type(q_dict)

# %%
# from langchain.llms import OpenAI
# from langchain.chains.summarize import load_summarize_chain
# from langchain.chains import AnalyzeDocumentChain

# llm = OpenAI(openai_api_key="",temperature=0)


# def summarize_doc(doc):
#     chain = load_summarize_chain(llm, chain_type="map_reduce")

#     summarize_document_chain = AnalyzeDocumentChain(combine_docs_chain=chain)

#     processed_doc = summarize_document_chain.run(doc)
      
#     return processed_doc


# for key, value in q_dict.items():
#     new_value = []
#     for doc in value:
#         new_value.append(summarize_doc(doc))
#     q_dict[key] = new_value

# %%
# q_dict['401	What language and cultural differences impede the integration of foreign minorities in Germany?']

# %%
# import json

# def save_dict_to_file(q_dict, filename):
#     with open(filename, 'w') as f:
#         json.dump(q_dict, f)

# save_dict_to_file(q_dict, 'q_dict401-450.txt')

# %%
# import json

# def load_dict_from_file(filename):
#     with open(filename, 'r') as f:
#         return json.load(f)

# q_dict = load_dict_from_file('q_dict401-450.txt')
# #print(q_dict['264014	how long is life cycle of flea'])

# %%
import json
import ast

with open("q_dict401-450.txt", "r", encoding="utf-8") as file:
    q_dict = ast.literal_eval(file.read())

# %%
import itertools
from openprompt.data_utils import InputExample

input_examples = []

#for querya_id_content, queryb_id_content in itertools.combinations(q_dict.keys(), 2):
for querya_id_content, queryb_id_content in itertools.permutations(q_dict.keys(), 2):

    querya_id, querya = querya_id_content.split('\t', 1)
    documentsa = q_dict[querya_id_content]
    
    queryb_id, queryb = queryb_id_content.split('\t', 1)
    documentsb = q_dict[queryb_id_content]
    
    t=querya_id+':'+queryb_id
    
    # InputExample
    input_example = InputExample(
        guid= len(input_examples),
        label= None,
        meta= {
            "queryaid": querya_id,
            "querya": querya,
            "documentsa": documentsa,
            "querybid": queryb_id,
            "queryb": queryb,
            "documentsb": documentsb
        },
        text_a= "",
        text_b= "",
        tgt_text= t
    )
    
    input_examples.append(input_example)

# %%
print(input_examples[0].meta['documentsa'])
# Out:
# [' Foreign Minister Klaus Kinkel believes the minority blocking vote in the European Union Council of Ministers is being overestimated and that the principle of unanimity and qualified majority vote are more important. He also rejects criticism from the CSU-led Bavarian Government that German interests are not being represented. He believes Germany is being viewed critically due to its past, but there is no reason to be overly cautious.', ' Ilan Mor, spokesman of the Israeli Embassy in Bonn, expresses his concern over the attack on a synagogue in Luebeck, Germany and believes that anti-Semitism exists in the country. He mentions an opinion poll which showed that 22% of people do not want a Jewish neighbor and emphasizes that Israel is closely monitoring events in Germany due to the events of 1933 and 1945.', ' German Chancellor Helmut Kohl is in a confrontation with Turkey over arms shipments, which must be used for defense within the NATO alliance. Hans-Ulrich Klose criticized Kohl for allowing the row to get out of hand. Meanwhile, the number of foreigners seeking political asylum in Germany has reached a record high of 35,000, with refugees from Yugoslavia, Romania, and Turkey making up the majority. In response to unrest in the Kurdish area, Turkey is introducing economic reforms to address the Kurdish problem.', ' The UK and Spain are seeking a legally binding protocol from Germany to give countries with 23-27 votes an automatic right to delay decisions, which could delay the entry of four new countries into the European Union. Greece has criticized the UK\'s stance as "blackmail of a tiny minority".', ' German Foreign Minister Klaus Kinkel spoke to the Bundestag in support of Russian President Yeltsin and the need for Russia to be integrated into the world economy. He also called for increased cultural exchange between European countries, with a focus on German language, and for more funds to be allocated to this purpose. He asked the Bundestag to provide the necessary support.']

# %%
documents = input_examples[0].meta['documentsa']
for example in input_examples:
    example.meta['documentsa'] = example.meta['documentsa'][0:1]
    
    example.meta['documentsb'] = example.meta['documentsb'][0:1]

# %%
documents = input_examples[0].meta['documentsa']

# %%
documents
# Out:
# [' Foreign Minister Klaus Kinkel believes the minority blocking vote in the European Union Council of Ministers is being overestimated and that the principle of unanimity and qualified majority vote are more important. He also rejects criticism from the CSU-led Bavarian Government that German interests are not being represented. He believes Germany is being viewed critically due to its past, but there is no reason to be overly cautious.']

# %%
for example in input_examples:
    documentsa = example.meta['documentsa']
    documentsa = [f'Document {i+1}: {doc}' for i, doc in enumerate(documentsa)]
    example.meta['documentsa'] = ' '.join(documentsa)

    documentsb = example.meta['documentsb']
    documentsb = [f'Document {i+1}: {doc}' for i, doc in enumerate(documentsb)]
    example.meta['documentsb'] = ' '.join(documentsb)

# %%
input_examples[0]
# Out:
# {
#   "guid": 0,
#   "label": null,
#   "meta": {
#     "documentsa": "Document 1:  Foreign Minister Klaus Kinkel believes the minority blocking vote in the European Union Council of Ministers is being overestimated and that the principle of unanimity and qualified majority vote are more important. He also rejects criticism from the CSU-led Bavarian Government that German interests are not being represented. He believes Germany is being viewed critically due to its past, but there is no reason to be overly cautious.",
#     "documentsb": "Document 1:  A landmark study on identical twins raised apart has found that genetics play a much larger role in shaping behavior than family environment. The study, published in the journal Science, found that 70% of intelligence quotient, 50% of personality differences, 50% of religiosity, and 40% of job interest variations are accounted for by genes. The Minnesota study of identical twins, begun in 1979, has revealed many eerie similarities between reunited twins and has been able to quantify the contribution of genetics to personality and behavior, while also emphasizing the importance of environment in child development.",
#     "querya": "What language and cultural differences impede the integration of foreign minorities in Germany?",
#     "queryaid": "401",
#     "queryb": "What is happening in the field of behavioral genetics, the study of the relative influence of genetic and environmental factors on an individual's behavior or personality?",
#     "querybid": "402"
#   },
#   "text_a": "",
#   "text_b": "",
#   "tgt_text": "401:402"
# }

# %%
# from transformers import GPT2LMHeadModel, GPT2Tokenizer
# from sklearn.feature_extraction.text import TfidfVectorizer
# import openai
# import os
# import nltk
# from langchain.chains.summarize import load_summarize_chain
# import textwrap
# from nltk.corpus import stopwords
# from nltk.tokenize import word_tokenize
# from nltk.stem import PorterStemmer
# from langchain import OpenAI, PromptTemplate, LLMChain
# from langchain.text_splitter import CharacterTextSplitter
# import string
# import numpy as np
# from langchain.chains.mapreduce import MapReduceChain
# from langchain.prompts import PromptTemplate


# nltk.download('punkt')
# nltk.download('stopwords')

# def preprocess(document):
#     # 转换为小写
#     document = document.lower()

#     # 去除标点符号
#     document = document.translate(str.maketrans('', '', string.punctuation))

#     # 分词
#     words = word_tokenize(document)

#     # 去除停止词
#     stop_words = set(stopwords.words('english'))
#     words = [word for word in words if word not in stop_words]

#     # 词干提取
# #     stemmer = PorterStemmer()
# #     words = [stemmer.stem(word) for word in words]

#     return ' '.join(words)



# documents = input_examples[0].meta['documentsa']
# print(input_examples[0].meta['querya'])


# # summaries = []
# # openai.api_key = "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"
# # #openai.api_key = os.environ["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"]
# # messages = [{"role": "user", "content": "介绍下 ChatGPT "}]
# # response = openai.ChatCompletion.create(
# #     model="gpt-3.5-turbo",
# #     messages=messages,
# #     temperature=0,
# # )
# # print("LLM 返回：", response.choices[0].message["content"])
# #     # 对摘要进行预处理
# #     summary = preprocess(summary)
# #     summaries.append(summary)
# # # 使用TF-IDF提取关键词
# i=0
# for doc in documents:
#     documents[i] = preprocess(doc)
#     i=i+1
# print(documents)
# vectorizer = TfidfVectorizer()
# X = vectorizer.fit_transform(documents)
# feature_array = np.array(vectorizer.get_feature_names_out())
# tfidf_sorting = np.argsort(X.toarray()).flatten()[::-1]
# n = 10
# top_n = feature_array[tfidf_sorting][:n]
# print(top_n)

# %%
# query_pairs = [(querya_id, queryb_id) for querya_id in q_dict for queryb_id in q_dict if querya_id > queryb_id]

# %%
# examples = []
# for i, (querya_id, queryb_id) in enumerate(query_pairs):
#     querya = querya_id
#     documentsa = q_dict[querya_id]
#     queryb = queryb_id
#     documentsb = q_dict[queryb_id]
#     examples.append(MyInput(guid=i, querya=querya, documentsa=documentsa, queryb=queryb, documentsb=documentsb))

# %%
import random

def random_query_from_file(file_name, count=2):
    with open(file_name, 'r') as file:
        queries = [line.strip().split('\t')[1] for line in file]  # extract query content
    return random.sample(queries, count)

# %%
text_list = []
for example in input_examples:
    s_queries = random_query_from_file('squery.txt', 4)
    g_queries = random_query_from_file('gquery.txt', 4)

    result1 = f'Query "{s_queries[0]}" is specific\n'
    result2 = f'Query "{s_queries[1]}" is specific\n'
    result3 = f'Query "{s_queries[2]}" is specific\n'
    result4 = f'Query "{s_queries[3]}" is specific\n'
    result5 = f'Query "{g_queries[0]}" is generic\n'
    result6 = f'Query "{g_queries[1]}" is generic\n'
    result7 = f'Query "{g_queries[2]}" is generic\n'
    result8 = f'Query "{g_queries[3]}" is generic\n'
    
    text = 'Given the following two queries: the first query is \"' + example.meta['querya'] + '\" and the second query is \"' + example.meta['queryb'] + '\" Compared to the first query, the second query is more {"mask"}.'
    #text = 'Given the following two queries and their respective top one document----the first query is \"' + example.meta['querya'] + '\" with its top one search result as \"' + example.meta['documentsa'] + '\", and the second query is \"' + example.meta['queryb'] + '\" with its top one search result as \"' + example.meta['documentsb'] + '\". Compared to the first query, the second query is more {"mask"}.'
    text=result1+result2+result3+result4+result5+result6+result7+result8+text
    text_list.append(text)

# %%
print(text_list[11])
# Out:
# Query "What was the impact of the Exxon Valdez oil spill on the marine life and wildlife of the area?" is specific
# Query "What violent activities have Kurds, or members of the Workers Party of Kurdistan (PKK), carried out in Germany?" is specific
# Query "Find documents that discuss banning leg traps used to capture animals." is specific
# Query "What adverse effects have people experienced while taking aspirin repeatedly?" is specific
# Query "What specific entities have been accused of illegal technology transfer such as: selling their products, formulas, etc. directly or indirectly to foreign entities for other than peaceful purposes?" is generic
# Query "Identify documents that discuss the education of children at home (home schooling)." is generic
# Query "Identify any actions being taken to propel the nations of the world toward a treaty banning the production, transfer and use of land mines." is generic
# Query "What methods are currently utilized or anticipated in the teaching of disabled children?" is generic
# Given the following two queries: the first query is "What language and cultural differences impede the integration of foreign minorities in Germany?" and the second query is "What are new methods of producing steel?" Compared to the first query, the second query is more {"mask"}.

# %%
for example in input_examples:
    example.meta['documentsa']=" "
    example.meta['documentsb']=" "

# %%
import os
os.environ["HF_DATASETS_CACHE"] = "D:\myplm"
os.environ["HF_HOME"] = "D:\myplm"
os.environ["HUGGINGFACE_HUB_CACHE"] = "D:\myplm"
os.environ["TRANSFORMERS_CACHE"] = "D:\myplm"

# %%
from openprompt.data_utils import InputExample
from openprompt.plms import load_plm
from openprompt.prompts import ManualTemplate
from openprompt.prompts import ManualVerbalizer
from openprompt import PromptForClassification
from openprompt import PromptDataLoader
from openprompt.plms.utils import TokenizerWrapper
from collections import defaultdict
import torch

classes = [ 
    "specific",
    "generic"
]
scores = defaultdict(float)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)


#plm, tokenizer, model_config, WrapperClass = load_plm("albert", "albert-base-v2")
#plm, tokenizer, model_config, WrapperClass = load_plm("roberta", "roberta-base")
plm, tokenizer, model_config, WrapperClass = load_plm("gpt2", "gpt2-large")
#plm, tokenizer, model_config, WrapperClass = load_plm("opt", "facebook/opt-iml-max-1.3b")
#plm, tokenizer, model_config, WrapperClass = load_plm("t5","google/flan-t5-base")


plm = plm.to(device)


x=0
for t in text_list:
    print("---------------------------------------------------------------")
    #print(t)
    dataset = []
    dataset.append(input_examples[x])
    x = x + 1
    promptTemplate = ManualTemplate(
        text = t,
        tokenizer = tokenizer,
    )
    promptVerbalizer = ManualVerbalizer(
        classes = classes,
        label_words = {
            "specific":["specific","precise","exact","well-formed","clear"],
            "generic":["generic","general","common","universal","ambiguous", "ill-formed", "vague"]
        },
        tokenizer = tokenizer,
    )
    promptModel = PromptForClassification(
        template = promptTemplate,
        plm = plm,
        verbalizer = promptVerbalizer,
    ).to(device)
    data_loader = PromptDataLoader(
        dataset = dataset,
        tokenizer = tokenizer,
        template = promptTemplate,
        tokenizer_wrapper_class=WrapperClass,
        #max_seq_length=512, decoder_max_length=3,batch_size=4,shuffle=False, teacher_forcing=False, predict_eos_token=False, truncate_method="tail"
    )
    promptModel.eval()
    with torch.no_grad():
        for batch in data_loader:
    
        
            batch = {key: value.to(device) if isinstance(value, torch.Tensor) else value for key, value in batch.items()}


        
            logits = promptModel(batch)
            preds = torch.argmax(logits, dim = -1)
            probs = torch.softmax(logits, dim=-1)
            
        
          
        for i, prob in enumerate(probs):
            
            query_id = batch['tgt_text'][i].split(':')[1]

            print(prob[classes.index('specific')],prob[classes.index('generic')])

            
            scores[query_id] += prob[classes.index('specific')]
# Out:
# cuda
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 27.77it/s]
# tensor(0.2781, device='cuda:0') tensor(0.7219, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 915.59it/s]
# tensor(0.2739, device='cuda:0') tensor(0.7261, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 680.56it/s]
# tensor(0.2438, device='cuda:0') tensor(0.7562, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.2213, device='cuda:0') tensor(0.7787, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.2185, device='cuda:0')
# tensor(0.7815, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.2429, device='cuda:0') tensor(0.7571, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.1742, device='cuda:0')
# tensor(0.8258, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 459.50it/s]
# tensor(0.2999, device='cuda:0')
# tensor(0.7001, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 517.30it/s]
# tensor(0.1910, device='cuda:0')
# tensor(0.8090, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.98it/s]
# tensor(0.3542, device='cuda:0') tensor(0.6458, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 500.04it/s]
# tensor(0.2016, device='cuda:0')
# tensor(0.7984, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.74it/s]
# tensor(0.1958, device='cuda:0')
# tensor(0.8042, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.92it/s]
# tensor(0.3438, device='cuda:0')
# tensor(0.6562, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 359.01it/s]
# tensor(0.2869, device='cuda:0')
# tensor(0.7131, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.92it/s]
# tensor(0.2768, device='cuda:0') tensor(0.7232, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 629.59it/s]
# tensor(0.2172, device='cuda:0') tensor(0.7828, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 569.03it/s]
# tensor(0.1541, device='cuda:0') tensor(0.8459, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 461.17it/s]
# tensor(0.1789, device='cuda:0') tensor(0.8211, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 500.16it/s]
# tensor(0.2786, device='cuda:0') tensor(0.7214, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 472.38it/s]
# tensor(0.2255, device='cuda:0') tensor(0.7745, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.80it/s]
# tensor(0.2203, device='cuda:0') tensor(0.7797, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.92it/s]
# tensor(0.3499, device='cuda:0') tensor(0.6501, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.68it/s]
# tensor(0.1819, device='cuda:0') tensor(0.8181, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 433.79it/s]
# tensor(0.1705, device='cuda:0') tensor(0.8295, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 426.81it/s]
# tensor(0.1905, device='cuda:0')
# tensor(0.8095, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.98it/s]
# tensor(0.1509, device='cuda:0')
# tensor(0.8491, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.92it/s]
# tensor(0.2107, device='cuda:0') tensor(0.7893, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.68it/s]
# tensor(0.2542, device='cuda:0')
# tensor(0.7458, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.38it/s]
# tensor(0.2167, device='cuda:0') tensor(0.7833, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 523.24it/s]
# tensor(0.1822, device='cuda:0') tensor(0.8178, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 459.10it/s]
# tensor(0.1970, device='cuda:0') tensor(0.8030, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.98it/s]
# tensor(0.2250, device='cuda:0') tensor(0.7750, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.92it/s]
# tensor(0.3613, device='cuda:0') tensor(0.6387, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 999.36it/s]
# tensor(0.2459, device='cuda:0')
# tensor(0.7541, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.2154, device='cuda:0') tensor(0.7846, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.98it/s]
# tensor(0.1753, device='cuda:0')
# tensor(0.8247, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.80it/s]
# tensor(0.3300, device='cuda:0') tensor(0.6700, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 999.60it/s]
# tensor(0.2645, device='cuda:0') tensor(0.7355, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 998.64it/s]
# tensor(0.1641, device='cuda:0') tensor(0.8359, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.80it/s]
# tensor(0.2375, device='cuda:0')
# tensor(0.7625, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.2434, device='cuda:0')
# tensor(0.7566, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 731.73it/s]
# tensor(0.2290, device='cuda:0')
# tensor(0.7710, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 639.38it/s]
# tensor(0.2418, device='cuda:0') tensor(0.7582, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.92it/s]
# tensor(0.1940, device='cuda:0') tensor(0.8060, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.80it/s]
# tensor(0.2081, device='cuda:0') tensor(0.7919, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 549.35it/s]
# tensor(0.2283, device='cuda:0') tensor(0.7717, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 500.10it/s]
# tensor(0.3065, device='cuda:0')
# tensor(0.6935, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.2009, device='cuda:0')
# tensor(0.7991, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.92it/s]
# tensor(0.3026, device='cuda:0')
# tensor(0.6974, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.98it/s]
# tensor(0.2632, device='cuda:0')
# tensor(0.7368, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.80it/s]
# tensor(0.2330, device='cuda:0')
# tensor(0.7670, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.74it/s]
# tensor(0.4009, device='cuda:0')
# tensor(0.5991, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.92it/s]
# tensor(0.2682, device='cuda:0')
# tensor(0.7318, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 517.11it/s]
# tensor(0.2511, device='cuda:0')
# tensor(0.7489, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 729.06it/s]
# tensor(0.2363, device='cuda:0') tensor(0.7637, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.80it/s]
# tensor(0.3092, device='cuda:0')
# tensor(0.6908, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 373.62it/s]
# tensor(0.2896, device='cuda:0') tensor(0.7104, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.92it/s]
# tensor(0.2515, device='cuda:0') tensor(0.7485, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.3613, device='cuda:0')
# tensor(0.6387, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.74it/s]
# tensor(0.2385, device='cuda:0')
# tensor(0.7615, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 510.57it/s]
# tensor(0.2550, device='cuda:0') tensor(0.7450, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.92it/s]
# tensor(0.6033, device='cuda:0')
# tensor(0.3967, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 478.04it/s]
# tensor(0.2959, device='cuda:0')
# tensor(0.7041, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 999.60it/s]
# tensor(0.3636, device='cuda:0') tensor(0.6364, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.98it/s]
# tensor(0.2173, device='cuda:0') tensor(0.7827, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.80it/s]
# tensor(0.2311, device='cuda:0') tensor(0.7689, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 500.04it/s]
# tensor(0.2061, device='cuda:0') tensor(0.7939, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.92it/s]
# tensor(0.2711, device='cuda:0') tensor(0.7289, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.3144, device='cuda:0') tensor(0.6856, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 660.10it/s]
# tensor(0.2761, device='cuda:0') tensor(0.7239, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 635.79it/s]
# tensor(0.3911, device='cuda:0') tensor(0.6089, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.2238, device='cuda:0') tensor(0.7762, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.2226, device='cuda:0') tensor(0.7774, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.98it/s]
# tensor(0.3333, device='cuda:0') tensor(0.6667, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.2484, device='cuda:0') tensor(0.7516, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.56it/s]
# tensor(0.2308, device='cuda:0') tensor(0.7692, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.2794, device='cuda:0')
# tensor(0.7206, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 407.85it/s]
# tensor(0.2472, device='cuda:0')
# tensor(0.7528, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.98it/s]
# tensor(0.2436, device='cuda:0')
# tensor(0.7564, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 938.11it/s]
# tensor(0.1654, device='cuda:0')
# tensor(0.8346, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.1597, device='cuda:0')
# tensor(0.8403, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 999.36it/s]
# tensor(0.3828, device='cuda:0') tensor(0.6172, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 405.99it/s]
# tensor(0.2589, device='cuda:0') tensor(0.7411, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.80it/s]
# tensor(0.3167, device='cuda:0')
# tensor(0.6833, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 999.83it/s]
# tensor(0.2430, device='cuda:0') tensor(0.7570, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.80it/s]
# tensor(0.3102, device='cuda:0') tensor(0.6898, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 438.69it/s]
# tensor(0.2567, device='cuda:0') tensor(0.7433, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 473.61it/s]
# tensor(0.2270, device='cuda:0') tensor(0.7730, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.74it/s]
# tensor(0.2824, device='cuda:0') tensor(0.7176, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.2805, device='cuda:0') tensor(0.7195, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 463.20it/s]
# tensor(0.3309, device='cuda:0') tensor(0.6691, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 999.83it/s]
# tensor(0.2454, device='cuda:0') tensor(0.7546, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 999.12it/s]
# tensor(0.1710, device='cuda:0') tensor(0.8290, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.98it/s]
# tensor(0.2555, device='cuda:0')
# tensor(0.7445, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.92it/s]
# tensor(0.2729, device='cuda:0') tensor(0.7271, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.92it/s]
# tensor(0.3097, device='cuda:0') tensor(0.6903, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 425.30it/s]
# tensor(0.2307, device='cuda:0') tensor(0.7693, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 1000.07it/s]
# tensor(0.3700, device='cuda:0') tensor(0.6300, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 393.83it/s]
# tensor(0.2760, device='cuda:0') tensor(0.7240, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.2220, device='cuda:0')
# tensor(0.7780, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.80it/s]
# tensor(0.4410, device='cuda:0')
# tensor(0.5590, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 385.19it/s]
# tensor(0.2109, device='cuda:0') tensor(0.7891, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.92it/s]
# tensor(0.2427, device='cuda:0')
# tensor(0.7573, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.2549, device='cuda:0') tensor(0.7451, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 333.33it/s]
# tensor(0.2206, device='cuda:0') tensor(0.7794, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 516.92it/s]
# tensor(0.3210, device='cuda:0') tensor(0.6790, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 1000.07it/s]
# tensor(0.2603, device='cuda:0') tensor(0.7397, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 634.64it/s]
# tensor(0.3683, device='cuda:0') tensor(0.6317, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 782.67it/s]
# tensor(0.2661, device='cuda:0') tensor(0.7339, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.1926, device='cuda:0') tensor(0.8074, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.74it/s]
# tensor(0.4592, device='cuda:0') tensor(0.5408, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 1078.78it/s]
# tensor(0.2096, device='cuda:0') tensor(0.7904, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 563.15it/s]
# tensor(0.3895, device='cuda:0') tensor(0.6105, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 569.96it/s]
# tensor(0.2440, device='cuda:0') tensor(0.7560, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 534.51it/s]
# tensor(0.2591, device='cuda:0')
# tensor(0.7409, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 519.61it/s]
# tensor(0.1853, device='cuda:0')
# tensor(0.8147, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.92it/s]
# tensor(0.2786, device='cuda:0')
# tensor(0.7214, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 517.56it/s]
# tensor(0.2529, device='cuda:0')
# tensor(0.7471, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 520.84it/s]
# tensor(0.2579, device='cuda:0')
# tensor(0.7421, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 500.10it/s]
# tensor(0.2943, device='cuda:0') tensor(0.7057, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 999.83it/s]
# tensor(0.2610, device='cuda:0')
# tensor(0.7390, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 502.25it/s]
# tensor(0.2044, device='cuda:0')
# tensor(0.7957, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.98it/s]
# tensor(0.4351, device='cuda:0')
# tensor(0.5649, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.2544, device='cuda:0')
# tensor(0.7456, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 534.31it/s]
# tensor(0.2753, device='cuda:0')
# tensor(0.7247, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 333.07it/s]
# tensor(0.2784, device='cuda:0') tensor(0.7216, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 540.64it/s]
# tensor(0.2387, device='cuda:0') tensor(0.7613, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.80it/s]
# tensor(0.3072, device='cuda:0') tensor(0.6928, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 500.04it/s]
# tensor(0.2182, device='cuda:0')
# tensor(0.7818, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 514.76it/s]
# tensor(0.1867, device='cuda:0')
# tensor(0.8133, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.2949, device='cuda:0')
# tensor(0.7051, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 500.04it/s]
# tensor(0.3204, device='cuda:0') tensor(0.6796, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 998.64it/s]
# tensor(0.2125, device='cuda:0')
# tensor(0.7875, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.1870, device='cuda:0') tensor(0.8130, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 333.28it/s]
# tensor(0.2810, device='cuda:0')
# tensor(0.7190, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 776.15it/s]
# tensor(0.2369, device='cuda:0')
# tensor(0.7631, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.2668, device='cuda:0') tensor(0.7332, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.2974, device='cuda:0') tensor(0.7026, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.74it/s]
# tensor(0.2968, device='cuda:0')
# tensor(0.7032, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 526.79it/s]
# tensor(0.3431, device='cuda:0')
# tensor(0.6569, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 949.80it/s]
# tensor(0.2066, device='cuda:0') tensor(0.7934, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.68it/s]
# tensor(0.2167, device='cuda:0') tensor(0.7833, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 500.04it/s]
# tensor(0.2883, device='cuda:0') tensor(0.7117, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.1852, device='cuda:0') tensor(0.8148, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.74it/s]
# tensor(0.4175, device='cuda:0')
# tensor(0.5825, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 469.48it/s]
# tensor(0.1868, device='cuda:0') tensor(0.8132, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.92it/s]
# tensor(0.3274, device='cuda:0') tensor(0.6726, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 509.39it/s]
# tensor(0.3410, device='cuda:0') tensor(0.6590, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 999.36it/s]
# tensor(0.2643, device='cuda:0') tensor(0.7357, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.98it/s]
# tensor(0.4683, device='cuda:0') tensor(0.5317, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 796.94it/s]
# tensor(0.2908, device='cuda:0') tensor(0.7092, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 999.12it/s]
# tensor(0.3288, device='cuda:0') tensor(0.6712, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 391.73it/s]
# tensor(0.2903, device='cuda:0')
# tensor(0.7097, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 691.79it/s]
# tensor(0.3054, device='cuda:0')
# tensor(0.6946, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.80it/s]
# tensor(0.4704, device='cuda:0') tensor(0.5296, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.98it/s]
# tensor(0.2523, device='cuda:0') tensor(0.7477, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.80it/s]
# tensor(0.3051, device='cuda:0') tensor(0.6949, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 361.92it/s]
# tensor(0.3364, device='cuda:0') tensor(0.6636, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 929.38it/s]
# tensor(0.2233, device='cuda:0') tensor(0.7767, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.92it/s]
# tensor(0.4994, device='cuda:0') tensor(0.5006, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 868.57it/s]
# tensor(0.3319, device='cuda:0') tensor(0.6681, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 1000.07it/s]
# tensor(0.4660, device='cuda:0') tensor(0.5340, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.62it/s]
# tensor(0.3190, device='cuda:0') tensor(0.6810, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.98it/s]
# tensor(0.2301, device='cuda:0') tensor(0.7699, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 421.07it/s]
# tensor(0.1035, device='cuda:0') tensor(0.8965, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 599.87it/s]
# tensor(0.4176, device='cuda:0') tensor(0.5824, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 538.63it/s]
# tensor(0.3478, device='cuda:0') tensor(0.6522, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 455.95it/s]
# tensor(0.1810, device='cuda:0') tensor(0.8190, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.3912, device='cuda:0')
# tensor(0.6088, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.92it/s]
# tensor(0.3296, device='cuda:0') tensor(0.6704, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 635.89it/s]
# tensor(0.2122, device='cuda:0') tensor(0.7878, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 999.60it/s]
# tensor(0.3395, device='cuda:0') tensor(0.6605, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.3503, device='cuda:0') tensor(0.6497, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 404.00it/s]
# tensor(0.3054, device='cuda:0') tensor(0.6946, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 596.71it/s]
# tensor(0.3669, device='cuda:0') tensor(0.6331, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.80it/s]
# tensor(0.3175, device='cuda:0') tensor(0.6825, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.2683, device='cuda:0') tensor(0.7317, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 500.04it/s]
# tensor(0.2300, device='cuda:0') tensor(0.7700, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 999.83it/s]
# tensor(0.2419, device='cuda:0') tensor(0.7581, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 820.96it/s]
# tensor(0.4667, device='cuda:0') tensor(0.5333, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 999.60it/s]
# tensor(0.2621, device='cuda:0') tensor(0.7379, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 438.46it/s]
# tensor(0.2801, device='cuda:0') tensor(0.7199, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 397.75it/s]
# tensor(0.2732, device='cuda:0') tensor(0.7268, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.3622, device='cuda:0') tensor(0.6378, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 645.18it/s]
# tensor(0.3310, device='cuda:0')
# tensor(0.6690, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 656.39it/s]
# tensor(0.2389, device='cuda:0') tensor(0.7611, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 600.13it/s]
# tensor(0.2559, device='cuda:0') tensor(0.7441, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 500.04it/s]
# tensor(0.3411, device='cuda:0') tensor(0.6589, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 941.69it/s]
# tensor(0.4292, device='cuda:0') tensor(0.5708, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 500.22it/s]
# tensor(0.1978, device='cuda:0') tensor(0.8022, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 487.09it/s]
# tensor(0.2513, device='cuda:0') tensor(0.7487, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.80it/s]
# tensor(0.3329, device='cuda:0') tensor(0.6671, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 735.07it/s]
# tensor(0.2369, device='cuda:0') tensor(0.7631, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.74it/s]
# tensor(0.3926, device='cuda:0')
# tensor(0.6074, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 740.52it/s]
# tensor(0.2319, device='cuda:0') tensor(0.7681, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 998.88it/s]
# tensor(0.5208, device='cuda:0') tensor(0.4792, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.98it/s]
# tensor(0.2146, device='cuda:0') tensor(0.7854, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 996.51it/s]
# tensor(0.2959, device='cuda:0') tensor(0.7041, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 476.95it/s]
# tensor(0.3821, device='cuda:0') tensor(0.6179, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 1000.07it/s]
# tensor(0.4107, device='cuda:0') tensor(0.5893, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.80it/s]
# tensor(0.2149, device='cuda:0') tensor(0.7851, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 999.60it/s]
# tensor(0.2313, device='cuda:0') tensor(0.7687, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 500.10it/s]
# tensor(0.2917, device='cuda:0') tensor(0.7083, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 415.03it/s]
# tensor(0.2863, device='cuda:0') tensor(0.7137, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 878.02it/s]
# tensor(0.2305, device='cuda:0') tensor(0.7695, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 574.56it/s]
# tensor(0.2366, device='cuda:0') tensor(0.7634, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.80it/s]
# tensor(0.3032, device='cuda:0')
# tensor(0.6968, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 636.37it/s]
# tensor(0.2157, device='cuda:0') tensor(0.7843, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 451.73it/s]
# tensor(0.4722, device='cuda:0') tensor(0.5278, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 500.04it/s]
# tensor(0.2433, device='cuda:0') tensor(0.7567, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 612.04it/s]
# tensor(0.3107, device='cuda:0')
# tensor(0.6893, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.68it/s]
# tensor(0.2100, device='cuda:0') tensor(0.7900, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 423.58it/s]
# tensor(0.1909, device='cuda:0') tensor(0.8091, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 698.82it/s]
# tensor(0.2671, device='cuda:0') tensor(0.7329, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 500.63it/s]
# tensor(0.2162, device='cuda:0') tensor(0.7838, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 585.22it/s]
# tensor(0.2722, device='cuda:0') tensor(0.7278, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 635.02it/s]
# tensor(0.2151, device='cuda:0') tensor(0.7849, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 500.04it/s]
# tensor(0.3113, device='cuda:0') tensor(0.6887, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.98it/s]
# tensor(0.2213, device='cuda:0') tensor(0.7787, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 484.05it/s]
# tensor(0.2012, device='cuda:0')
# tensor(0.7988, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.68it/s]
# tensor(0.3344, device='cuda:0') tensor(0.6656, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.92it/s]
# tensor(0.2076, device='cuda:0')
# tensor(0.7924, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.92it/s]
# tensor(0.2624, device='cuda:0')
# tensor(0.7376, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 500.10it/s]
# tensor(0.2892, device='cuda:0')
# tensor(0.7108, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.98it/s]
# tensor(0.2569, device='cuda:0') tensor(0.7431, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 366.63it/s]
# tensor(0.2174, device='cuda:0') tensor(0.7826, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 999.60it/s]
# tensor(0.2113, device='cuda:0') tensor(0.7887, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 1000.07it/s]
# tensor(0.1760, device='cuda:0') tensor(0.8240, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 500.22it/s]
# tensor(0.3570, device='cuda:0')
# tensor(0.6430, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.74it/s]
# tensor(0.3057, device='cuda:0') tensor(0.6943, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 999.60it/s]
# tensor(0.2490, device='cuda:0') tensor(0.7510, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 753.42it/s]
# tensor(0.2232, device='cuda:0') tensor(0.7768, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 518.01it/s]
# tensor(0.2790, device='cuda:0') tensor(0.7210, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 587.19it/s]
# tensor(0.2712, device='cuda:0')
# tensor(0.7288, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 599.96it/s]
# tensor(0.2236, device='cuda:0') tensor(0.7764, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.92it/s]
# tensor(0.2277, device='cuda:0') tensor(0.7723, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 500.33it/s]
# tensor(0.3171, device='cuda:0') tensor(0.6829, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.92it/s]
# tensor(0.2773, device='cuda:0')
# tensor(0.7227, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.1877, device='cuda:0')
# tensor(0.8123, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 525.14it/s]
# tensor(0.2332, device='cuda:0')
# tensor(0.7668, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 1000.07it/s]
# tensor(0.2968, device='cuda:0')
# tensor(0.7032, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 570.89it/s]
# tensor(0.2422, device='cuda:0') tensor(0.7578, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.3090, device='cuda:0') tensor(0.6910, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.92it/s]
# tensor(0.2855, device='cuda:0') tensor(0.7145, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 333.30it/s]
# tensor(0.3745, device='cuda:0') tensor(0.6255, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.80it/s]
# tensor(0.2794, device='cuda:0')
# tensor(0.7206, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.80it/s]
# tensor(0.2396, device='cuda:0') tensor(0.7604, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 503.16it/s]
# tensor(0.3327, device='cuda:0') tensor(0.6673, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.68it/s]
# tensor(0.4593, device='cuda:0') tensor(0.5407, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 1001.03it/s]
# tensor(0.3148, device='cuda:0') tensor(0.6852, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 941.48it/s]
# tensor(0.2160, device='cuda:0') tensor(0.7840, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 472.17it/s]
# tensor(0.3044, device='cuda:0') tensor(0.6956, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.80it/s]
# tensor(0.3506, device='cuda:0')
# tensor(0.6494, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 500.10it/s]
# tensor(0.1750, device='cuda:0') tensor(0.8250, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 567.49it/s]
# tensor(0.3730, device='cuda:0')
# tensor(0.6270, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 412.38it/s]
# tensor(0.3136, device='cuda:0')
# tensor(0.6864, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.92it/s]
# tensor(0.2559, device='cuda:0')
# tensor(0.7441, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.92it/s]
# tensor(0.5093, device='cuda:0') tensor(0.4907, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.1788, device='cuda:0')
# tensor(0.8212, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.74it/s]
# tensor(0.2956, device='cuda:0') tensor(0.7044, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 436.59it/s]
# tensor(0.2156, device='cuda:0') tensor(0.7844, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.98it/s]
# tensor(0.2126, device='cuda:0') tensor(0.7874, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 500.10it/s]
# tensor(0.1761, device='cuda:0') tensor(0.8239, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 430.98it/s]
# tensor(0.1963, device='cuda:0')
# tensor(0.8037, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.80it/s]
# tensor(0.3017, device='cuda:0') tensor(0.6983, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 999.36it/s]
# tensor(0.2044, device='cuda:0')
# tensor(0.7956, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.68it/s]
# tensor(0.3278, device='cuda:0')
# tensor(0.6722, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 426.60it/s]
# tensor(0.2167, device='cuda:0') tensor(0.7833, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 620.28it/s]
# tensor(0.1825, device='cuda:0') tensor(0.8175, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 500.45it/s]
# tensor(0.2934, device='cuda:0') tensor(0.7066, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.80it/s]
# tensor(0.3194, device='cuda:0') tensor(0.6806, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 611.86it/s]
# tensor(0.2209, device='cuda:0') tensor(0.7791, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 492.98it/s]
# tensor(0.2208, device='cuda:0') tensor(0.7792, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.92it/s]
# tensor(0.2262, device='cuda:0') tensor(0.7738, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 575.90it/s]
# tensor(0.2198, device='cuda:0') tensor(0.7802, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.1622, device='cuda:0') tensor(0.8378, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 998.88it/s]
# tensor(0.1664, device='cuda:0') tensor(0.8336, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 1000.07it/s]
# tensor(0.3213, device='cuda:0') tensor(0.6787, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 456.40it/s]
# tensor(0.3193, device='cuda:0') tensor(0.6807, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.92it/s]
# tensor(0.1826, device='cuda:0')
# tensor(0.8174, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 709.70it/s]
# tensor(0.2480, device='cuda:0') tensor(0.7520, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 516.79it/s]
# tensor(0.3639, device='cuda:0') tensor(0.6361, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.80it/s]
# tensor(0.2430, device='cuda:0') tensor(0.7570, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 1000.31it/s]
# tensor(0.2308, device='cuda:0') tensor(0.7692, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 742.75it/s]
# tensor(0.2618, device='cuda:0') tensor(0.7382, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 608.66it/s]
# tensor(0.2229, device='cuda:0') tensor(0.7771, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.3582, device='cuda:0') tensor(0.6418, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 999.83it/s]
# tensor(0.2017, device='cuda:0') tensor(0.7983, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 401.98it/s]
# tensor(0.2435, device='cuda:0')
# tensor(0.7565, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 519.23it/s]
# tensor(0.2002, device='cuda:0') tensor(0.7998, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.2243, device='cuda:0')
# tensor(0.7757, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.3087, device='cuda:0') tensor(0.6913, device='cuda:0')
# ---------------------------------------------------------------
# ...
# tensor(0.3022, device='cuda:0') tensor(0.6978, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.1983, device='cuda:0') tensor(0.8017, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 999.83it/s]
# tensor(0.3077, device='cuda:0')
# tensor(0.6923, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 788.55it/s]
# tensor(0.3321, device='cuda:0') tensor(0.6679, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.2544, device='cuda:0')
# tensor(0.7456, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.2148, device='cuda:0')
# tensor(0.7852, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.74it/s]
# tensor(0.2152, device='cuda:0')
# tensor(0.7848, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 823.38it/s]
# tensor(0.2630, device='cuda:0') tensor(0.7370, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 500.04it/s]
# tensor(0.2511, device='cuda:0') tensor(0.7489, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 476.30it/s]
# tensor(0.1957, device='cuda:0') tensor(0.8043, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 512.88it/s]
# tensor(0.3170, device='cuda:0')
# tensor(0.6830, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.80it/s]
# tensor(0.2265, device='cuda:0') tensor(0.7735, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 624.06it/s]
# tensor(0.1852, device='cuda:0') tensor(0.8148, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 950.87it/s]
# tensor(0.4558, device='cuda:0') tensor(0.5442, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.92it/s]
# tensor(0.2073, device='cuda:0') tensor(0.7927, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.92it/s]
# tensor(0.3012, device='cuda:0') tensor(0.6988, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 999.83it/s]
# tensor(0.2754, device='cuda:0') tensor(0.7246, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.80it/s]
# tensor(0.1644, device='cuda:0')
# tensor(0.8356, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 498.97it/s]
# tensor(0.1841, device='cuda:0') tensor(0.8159, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 393.87it/s]
# tensor(0.1868, device='cuda:0') tensor(0.8132, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 542.67it/s]
# tensor(0.2390, device='cuda:0')
# tensor(0.7610, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.74it/s]
# tensor(0.1921, device='cuda:0') tensor(0.8079, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 695.11it/s]
# tensor(0.2778, device='cuda:0') tensor(0.7222, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 855.28it/s]
# tensor(0.1817, device='cuda:0') tensor(0.8183, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 364.50it/s]
# tensor(0.1652, device='cuda:0') tensor(0.8348, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 424.83it/s]
# tensor(0.3087, device='cuda:0') tensor(0.6913, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.3114, device='cuda:0')
# tensor(0.6886, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.80it/s]
# tensor(0.2780, device='cuda:0') tensor(0.7220, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 511.00it/s]
# tensor(0.2484, device='cuda:0') tensor(0.7516, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.80it/s]
# tensor(0.2123, device='cuda:0') tensor(0.7877, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.80it/s]
# tensor(0.2209, device='cuda:0') tensor(0.7791, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.1543, device='cuda:0') tensor(0.8457, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.1876, device='cuda:0')
# tensor(0.8124, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.74it/s]
# tensor(0.3708, device='cuda:0') tensor(0.6292, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 378.27it/s]
# tensor(0.2264, device='cuda:0')
# tensor(0.7736, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 538.15it/s]
# tensor(0.2047, device='cuda:0') tensor(0.7953, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 631.01it/s]
# tensor(0.1774, device='cuda:0') tensor(0.8226, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.74it/s]
# tensor(0.2255, device='cuda:0') tensor(0.7745, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 530.99it/s]
# tensor(0.1893, device='cuda:0') tensor(0.8107, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 859.49it/s]
# tensor(0.2153, device='cuda:0') tensor(0.7847, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 484.61it/s]
# tensor(0.1965, device='cuda:0') tensor(0.8035, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 600.99it/s]
# tensor(0.2480, device='cuda:0')
# tensor(0.7520, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 649.47it/s]
# tensor(0.3655, device='cuda:0')
# tensor(0.6345, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 999.83it/s]
# tensor(0.1857, device='cuda:0') tensor(0.8143, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.98it/s]
# tensor(0.1608, device='cuda:0') tensor(0.8392, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 507.78it/s]
# tensor(0.2201, device='cuda:0') tensor(0.7799, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 999.36it/s]
# tensor(0.2318, device='cuda:0') tensor(0.7682, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 798.00it/s]
# tensor(0.2958, device='cuda:0') tensor(0.7042, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 928.77it/s]
# tensor(0.4182, device='cuda:0') tensor(0.5818, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 486.58it/s]
# tensor(0.2706, device='cuda:0') tensor(0.7294, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.92it/s]
# tensor(0.2625, device='cuda:0') tensor(0.7375, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 480.56it/s]
# tensor(0.2996, device='cuda:0') tensor(0.7004, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.5482, device='cuda:0') tensor(0.4518, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 580.37it/s]
# tensor(0.3074, device='cuda:0') tensor(0.6926, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.68it/s]
# tensor(0.2622, device='cuda:0') tensor(0.7378, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 515.46it/s]
# tensor(0.3503, device='cuda:0') tensor(0.6497, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 566.03it/s]
# tensor(0.3579, device='cuda:0')
# tensor(0.6421, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 999.60it/s]
# tensor(0.3585, device='cuda:0')
# tensor(0.6415, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 500.16it/s]
# tensor(0.2725, device='cuda:0')
# tensor(0.7275, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 999.83it/s]
# tensor(0.3549, device='cuda:0')
# tensor(0.6451, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.3187, device='cuda:0') tensor(0.6813, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.74it/s]
# tensor(0.3156, device='cuda:0')
# tensor(0.6844, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 515.33it/s]
# tensor(0.3690, device='cuda:0') tensor(0.6310, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 498.61it/s]
# tensor(0.2778, device='cuda:0') tensor(0.7222, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 597.73it/s]
# tensor(0.3150, device='cuda:0') tensor(0.6850, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.80it/s]
# tensor(0.3454, device='cuda:0') tensor(0.6546, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.2529, device='cuda:0') tensor(0.7471, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 515.27it/s]
# tensor(0.2743, device='cuda:0') tensor(0.7257, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 362.30it/s]
# tensor(0.3632, device='cuda:0') tensor(0.6368, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 481.61it/s]
# tensor(0.2574, device='cuda:0') tensor(0.7426, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 484.50it/s]
# tensor(0.2265, device='cuda:0')
# tensor(0.7735, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.80it/s]
# tensor(0.4070, device='cuda:0') tensor(0.5930, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 1000.07it/s]
# tensor(0.2780, device='cuda:0') tensor(0.7220, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 480.45it/s]
# tensor(0.2232, device='cuda:0') tensor(0.7768, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 683.00it/s]
# tensor(0.3954, device='cuda:0') tensor(0.6046, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.2748, device='cuda:0') tensor(0.7252, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 486.63it/s]
# tensor(0.2983, device='cuda:0') tensor(0.7017, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.3780, device='cuda:0') tensor(0.6220, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 1000.31it/s]
# tensor(0.2383, device='cuda:0') tensor(0.7617, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.3542, device='cuda:0') tensor(0.6458, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 731.48it/s]
# tensor(0.2317, device='cuda:0') tensor(0.7683, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 999.83it/s]
# tensor(0.2911, device='cuda:0') tensor(0.7089, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 500.16it/s]
# tensor(0.5175, device='cuda:0') tensor(0.4825, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.80it/s]
# tensor(0.3121, device='cuda:0') tensor(0.6879, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.98it/s]
# tensor(0.2238, device='cuda:0') tensor(0.7762, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.86it/s]
# tensor(0.2692, device='cuda:0')
# tensor(0.7308, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.92it/s]
# tensor(0.3851, device='cuda:0')
# tensor(0.6149, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.74it/s]
# tensor(0.3097, device='cuda:0') tensor(0.6903, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 575.90it/s]
# tensor(0.3423, device='cuda:0') tensor(0.6577, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 477.17it/s]
# tensor(0.2918, device='cuda:0') tensor(0.7082, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 415.11it/s]
# tensor(0.4024, device='cuda:0') tensor(0.5976, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 394.50it/s]
# tensor(0.3831, device='cuda:0') tensor(0.6169, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 463.05it/s]
# tensor(0.2351, device='cuda:0')
# tensor(0.7649, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 398.66it/s]
# tensor(0.2314, device='cuda:0') tensor(0.7686, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 500.04it/s]
# tensor(0.2846, device='cuda:0') tensor(0.7154, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.74it/s]
# tensor(0.2651, device='cuda:0') tensor(0.7349, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 499.20it/s]
# tensor(0.4423, device='cuda:0')
# tensor(0.5577, device='cuda:0')
# ---------------------------------------------------------------
# tokenizing: 1it [00:00, 500.27it/s]
# tensor(0.2738, device='cuda:0') tensor(0.7262, device='cuda:0')

# %%
import torch
import torchvision
import torchaudio
torch.cuda.is_available()
# Out:
# C:\Users\86178\.conda\envs\myenvi\lib\site-packages\torchaudio\backend\utils.py:62: UserWarning: No audio backend is available.
#   warnings.warn("No audio backend is available.")
# True

# %%
import torch
print(torch.__version__)
print(torch.version.cuda)
# Out:
# 1.12.1
# 11.6

# %%
# import torch

# promptModel.eval()
# with torch.no_grad():
#     for batch in data_loader:
#         logits = promptModel(batch)
#         print(batch.tgt_text)
#         preds = torch.argmax(logits, dim = -1)
#         #print(preds)
#         print(classes[preds])
sorted_queries = sorted(scores.items(), key=lambda item: item[1], reverse=True)

# %%
sorted_queries
# Out:
# [('414', tensor(21.7669, device='cuda:0')),
#  ('450', tensor(19.4389, device='cuda:0')),
#  ('434', tensor(18.2256, device='cuda:0')),
#  ('404', tensor(18.1159, device='cuda:0')),
#  ('423', tensor(17.1363, device='cuda:0')),
#  ('411', tensor(17.1309, device='cuda:0')),
#  ('409', tensor(16.7745, device='cuda:0')),
#  ('443', tensor(16.5580, device='cuda:0')),
#  ('416', tensor(16.3709, device='cuda:0')),
#  ('448', tensor(16.2835, device='cuda:0')),
#  ('438', tensor(15.6995, device='cuda:0')),
#  ('426', tensor(15.5394, device='cuda:0')),
#  ('403', tensor(15.0544, device='cuda:0')),
#  ('421', tensor(14.3556, device='cuda:0')),
#  ('429', tensor(13.9962, device='cuda:0')),
#  ('408', tensor(13.8417, device='cuda:0')),
#  ('412', tensor(13.5421, device='cuda:0')),
#  ('435', tensor(13.4297, device='cuda:0')),
#  ('442', tensor(13.1966, device='cuda:0')),
#  ('407', tensor(12.9292, device='cuda:0')),
#  ('405', tensor(12.8474, device='cuda:0')),
#  ('420', tensor(12.8288, device='cuda:0')),
#  ('431', tensor(12.6614, device='cuda:0')),
#  ('446', tensor(12.6048, device='cuda:0')),
#  ('427', tensor(12.5483, device='cuda:0')),
#  ('430', tensor(12.5335, device='cuda:0')),
#  ('415', tensor(12.3784, device='cuda:0')),
#  ('428', tensor(12.1746, device='cuda:0')),
#  ('402', tensor(12.1407, device='cuda:0')),
#  ('417', tensor(12.1176, device='cuda:0')),
#  ('439', tensor(12.0578, device='cuda:0')),
#  ('401', tensor(11.9897, device='cuda:0')),
#  ('406', tensor(11.7922, device='cuda:0')),
#  ('441', tensor(11.6168, device='cuda:0')),
#  ('440', tensor(11.3642, device='cuda:0')),
#  ('424', tensor(11.3181, device='cuda:0')),
#  ('436', tensor(11.2225, device='cuda:0')),
#  ('447', tensor(10.9185, device='cuda:0')),
#  ('413', tensor(10.9045, device='cuda:0')),
#  ('410', tensor(10.8058, device='cuda:0')),
#  ('422', tensor(10.7754, device='cuda:0')),
#  ('449', tensor(10.7049, device='cuda:0')),
#  ('437', tensor(10.6177, device='cuda:0')),
#  ('418', tensor(10.3425, device='cuda:0')),
#  ('419', tensor(10.1407, device='cuda:0')),
#  ('444', tensor(10.0897, device='cuda:0')),
#  ('445', tensor(9.9181, device='cuda:0')),
#  ('425', tensor(9.5634, device='cuda:0')),
#  ('432', tensor(9.2360, device='cuda:0')),
#  ('433', tensor(8.9857, device='cuda:0'))]

# %%
query_dict = dict(sorted_queries)

# %%
query_dict = {k: v.item() for k, v in query_dict.items()}

# %%
query_dict
# Out:
# {'414': 21.766862869262695,
#  '450': 19.438888549804688,
#  '434': 18.225587844848633,
#  '404': 18.115863800048828,
#  '423': 17.136272430419922,
#  '411': 17.130918502807617,
#  '409': 16.774518966674805,
#  '443': 16.557979583740234,
#  '416': 16.37088966369629,
#  '448': 16.283493041992188,
#  '438': 15.699469566345215,
#  '426': 15.539405822753906,
#  '403': 15.054422378540039,
#  '421': 14.355643272399902,
#  '429': 13.996193885803223,
#  '408': 13.841663360595703,
#  '412': 13.542142868041992,
#  '435': 13.42971420288086,
#  '442': 13.196601867675781,
#  '407': 12.929187774658203,
#  '405': 12.847357749938965,
#  '420': 12.828828811645508,
#  '431': 12.661447525024414,
#  '446': 12.60480785369873,
#  '427': 12.54830265045166,
#  '430': 12.533489227294922,
#  '415': 12.378434181213379,
#  '428': 12.174626350402832,
#  '402': 12.140701293945312,
#  '417': 12.117609024047852,
#  '439': 12.057833671569824,
#  '401': 11.989653587341309,
#  '406': 11.792243003845215,
#  '441': 11.616814613342285,
#  '440': 11.364200592041016,
#  '424': 11.318079948425293,
#  '436': 11.222549438476562,
#  '447': 10.918465614318848,
#  '413': 10.904533386230469,
#  '410': 10.8058443069458,
#  '422': 10.77539348602295,
#  '449': 10.70486831665039,
#  '437': 10.61767864227295,
#  '418': 10.34249210357666,
#  '419': 10.140715599060059,
#  '444': 10.089690208435059,
#  '445': 9.918061256408691,
#  '425': 9.56340217590332,
#  '432': 9.235998153686523,
#  '433': 8.98571491241455}

# %%
with open('401-450gt.txt', 'r') as f:
    gt = dict(line.strip().split() for line in f)

with open('401-450nqc.txt', 'r') as f:
    nqc = dict(line.strip().split() for line in f)

query_scores = list(query_dict.values())
#gtscores = [float(gt[key]) for key in query_dict.keys()]
#nqcscores = [float(nqc[key]) for key in query_dict.keys()]

# %%
keys = query_dict.keys()
gtscores = [float(gt[key]) for key in keys]
nqcscores = [float(nqc[key]) for key in keys]

# %%
keys
# Out:
# dict_keys(['414', '450', '434', '404', '423', '411', '409', '443', '416', '448', '438', '426', '403', '421', '429', '408', '412', '435', '442', '407', '405', '420', '431', '446', '427', '430', '415', '428', '402', '417', '439', '401', '406', '441', '440', '424', '436', '447', '413', '410', '422', '449', '437', '418', '419', '444', '445', '425', '432', '433'])

# %%
len(query_dict)
# Out:
# 50

# %%
with open('flant5_pair_pre_s4.txt', 'w', encoding='utf-8') as f:
    for key in query_dict.keys():
        f.write(f'{key}\t{query_dict[key]}\t{nqc[key]}\t{gt[key]}\n')

# %%
len(nqcscores)
# Out:
# 50

# %%
from scipy.stats import pearsonr
p1 = pearsonr(query_scores, gtscores)
p2 = pearsonr(nqcscores, gtscores)
print(p1)
print(p2)
# Out:
# PearsonRResult(statistic=0.0787363023653114, pvalue=0.5867767009110734)
# PearsonRResult(statistic=0.36221728005952814, pvalue=0.009740338185571422)

# %%
from scipy.stats import kendalltau
k1 = kendalltau(query_scores, gtscores)
k2 = kendalltau(nqcscores, gtscores)
print(k1)
print(k2)
# Out:
# SignificanceResult(statistic=0.1346938775510204, pvalue=0.16752460252559542)
# SignificanceResult(statistic=0.23265306122448978, pvalue=0.01712632537811409)

# %%
print(plm.config)
# Out:
# T5Config {
#   "_name_or_path": "google/flan-t5-base",
#   "architectures": [
#     "T5ForConditionalGeneration"
#   ],
#   "d_ff": 2048,
#   "d_kv": 64,
#   "d_model": 768,
#   "decoder_start_token_id": 0,
#   "dropout_rate": 0.1,
#   "eos_token_id": 1,
#   "feed_forward_proj": "gated-gelu",
#   "initializer_factor": 1.0,
#   "is_encoder_decoder": true,
#   "layer_norm_epsilon": 1e-06,
#   "model_type": "t5",
#   "n_positions": 512,
#   "num_decoder_layers": 12,
#   "num_heads": 12,
#   "num_layers": 12,
#   "output_past": true,
#   "pad_token_id": 0,
#   "relative_attention_max_distance": 128,
#   "relative_attention_num_buckets": 32,
#   "task_specific_params": {
#     "summarization": {
#       "early_stopping": true,
#       "length_penalty": 2.0,
#       "max_length": 200,
#       "min_length": 30,
#       "no_repeat_ngram_size": 3,
#       "num_beams": 4,
#       "prefix": "summarize: "
#     },
#     "translation_en_to_de": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to German: "
#     },
#     "translation_en_to_fr": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to French: "
#     },
#     "translation_en_to_ro": {
#       "early_stopping": true,
#       "max_length": 300,
#       "num_beams": 4,
#       "prefix": "translate English to Romanian: "
#     }
#   },
#   "tie_word_embeddings": false,
#   "transformers_version": "4.19.0",
#   "use_cache": true,
#   "vocab_size": 32128
# }
